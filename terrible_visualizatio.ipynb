# %%
import pandas as pd
import seaborn as sns

# %%
fb = pd.read_csv('./results_year.csv')
fb.head()
# Out:
#    country  year  neutral  home_win  away_win  games_played  goal_diff  \
# 0  Austria  2010        0         1         0             4         -1
# 1  Austria  2011        0         1         0             6         -8
# 2  Austria  2012        0         1         0             3          1
# 3  Austria  2013        0         1         0             4         -5
# 4  Austria  2014        0         0         0             1          0
#
#    win_rate
# 0  0.250000
# 1  0.166667
# 2  0.333333
# 3  0.250000
# 4  0.000000

# %%
lp = sns.lineplot(data=fb, x="year", y="win_rate", hue="country")
sns.set(rc={'figure.figsize':(17,13)})
lp.legend_ = None
